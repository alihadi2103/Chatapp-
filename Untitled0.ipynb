# %% [markdown]
# <a href="https://colab.research.google.com/github/alihadi2103/Chatapp-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install llama-index-llms-gemini
# !pip install -q llama-index google-generativeai
# !pip install llama-index
# %env GOOGLE_API_KEY="AIzaSyBUscN6A-5ooavWBuHIbZ3M99pbsBZIcjU"

# %% [markdown]
# ## The Imports Section

# %%
from llama_index.llms.gemini import Gemini
from llama_index.core.llms import ChatMessage
import google.generativeai as genai
from llama_index.core.prompts import PromptTemplate
from llama_index.core import Settings

# %% [markdown]
# # CONFIGURATION OF THE LLM

# %%
genai.configure(api_key="AIzaSyBUscN6A-5ooavWBuHIbZ3M99pbsBZIcjU")
Settings.llm = Gemini(model="models/gemini-1.5-pro", api_key="AIzaSyBUscN6A-5ooavWBuHIbZ3M99pbsBZIcjU")
Settings.embed_model=genai.get_model("models/text-embedding-004")

# %% [markdown]
# # Function that ge the embedding of the Text

# %%
def get_embeding(content):
    content=content.replace('\n','').strip()
    print(content)
    result = genai.embed_content(model="models/text-embedding-004",content=content)
    return result

# %%
get_embeding("thi is the new \n Generation")
# Out:
# thi is the new  Generation
# {'embedding': [-0.04325636,
#   0.01573708,
#   -0.06741846,
#   -0.03097778,
#   0.046198584,
#   0.0069817333,
#   0.021094505,
#   0.044977576,
#   0.0050692568,
#   -0.010811451,
#   -0.01577978,
#   0.074754946,
#   0.0005089066,
#   0.03159033,
#   -0.022580454,
#   -0.005801633,
#   0.0062616244,
#   0.029497784,
#   -0.101721905,
#   -0.008595579,
#   0.013617307,
#   -0.010722721,
#   -0.03768031,
#   -0.008607562,
#   -0.028074473,
#   0.008733215,
#   0.05249913,
#   0.040538035,
#   -0.012818507,
#   0.004492591,
#   -0.0058869906,
#   0.089278765,
#   -0.0009508005,
#   0.09503403,
#   0.009933739,
#   -0.022202278,
#   -0.03464914,
#   0.054276444,
#   -0.001221363,
#   -0.025429003,
#   -0.034370176,
#   0.026265591,
#   -0.042825412,
#   -0.026398715,
#   0.005244983,
#   -0.006429946,
#   0.04138145,
#   -0.0048404816,
#   -0.03543069,
#   0.0039433893,
#   -0.0032738717,
#   -0.08076183,
#   -0.04635617,
#   0.005390988,
# ...

# %% [markdown]
# **
